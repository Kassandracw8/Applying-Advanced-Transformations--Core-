# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df=pd.read_csv(r"C:\Users\dhowa\Downloads\superhero_info - superhero_info.csv")
df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df['Hero|Publisher'].head(2)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# Name: Hero|Publisher, dtype: object

# %%
df[['Hero','Publisher']] = df['Hero|Publisher'].str.split('|',expand=True)
df.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
df = df.drop(columns=['Hero|Publisher'])
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %%
heigh = df.loc[0,"Measurements"]
print(type(heigh))
heigh
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
df['Measurements'] = df['Measurements'].str.replace("'",'"').str.replace(" cm","").str.replace(" kg","")
## Apply the json.loads to the full column
df['Measurements'] = df['Measurements'].apply(json.loads)
df['Measurements'].head()
# Out:
# 0    {'Height': '203.0', 'Weight': '441.0'}
# 1     {'Height': '191.0', 'Weight': '65.0'}
# 2     {'Height': '185.0', 'Weight': '90.0'}
# 3    {'Height': '203.0', 'Weight': '441.0'}
# 4    {'Height': '193.0', 'Weight': '122.0'}
# Name: Measurements, dtype: object

# %%
heigh_weigh = df['Measurements'].apply(pd.Series)
heigh_weigh
# Out:
#     Height Weight
# 0    203.0  441.0
# 1    191.0   65.0
# 2    185.0   90.0
# 3    203.0  441.0
# 4    193.0  122.0
# ..     ...    ...
# 458  183.0   83.0
# 459  165.0   52.0
# 460   66.0   17.0
# 461  170.0   57.0
# 462  185.0   81.0
#
# [463 rows x 2 columns]

# %%
df = pd.concat((df, heigh_weigh), axis = 1)
df.head(10)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
# 5   Male              Human      good      Blond      blue    Unknown
# 6   Male              Human      good      Brown     brown    Unknown
# 7   Male            Unknown      good    Unknown   Unknown    Unknown
# 8   Male            Unknown       bad      White      blue    Unknown
# 9   Male             Cyborg       bad      Black     brown    Unknown
#
#                              Measurements           Hero          Publisher  \
# 0  {'Height': '203.0', 'Weight': '441.0'}         A-Bomb      Marvel Comics
# 1   {'Height': '191.0', 'Weight': '65.0'}     Abe Sapien  Dark Horse Comics
# 2   {'Height': '185.0', 'Weight': '90.0'}       Abin Sur          DC Comics
# 3  {'Height': '203.0', 'Weight': '441.0'}    Abomination      Marvel Comics
# 4  {'Height': '193.0', 'Weight': '122.0'}  Absorbing Man      Marvel Comics
# 5   {'Height': '185.0', 'Weight': '88.0'}   Adam Strange          DC Comics
# 6   {'Height': '178.0', 'Weight': '81.0'}      Agent Bob      Marvel Comics
# 7  {'Height': '191.0', 'Weight': '104.0'}     Agent Zero      Marvel Comics
# 8  {'Height': '188.0', 'Weight': '108.0'}     Air-Walker      Marvel Comics
# 9   {'Height': '193.0', 'Weight': '90.0'}           Ajax      Marvel Comics
#
#   Height Weight
# 0  203.0  441.0
# 1  191.0   65.0
# 2  185.0   90.0
# 3  203.0  441.0
# 4  193.0  122.0
# 5  185.0   88.0
# 6  178.0   81.0
# 7  191.0  104.0
# 8  188.0  108.0
# 9  193.0   90.0

# %%
df = df.drop(columns=['Measurements'])
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height Weight
# 0      Marvel Comics  203.0  441.0
# 1  Dark Horse Comics  191.0   65.0

# %%
df2=pd.read_csv(r"C:\Users\dhowa\Downloads\superhero_powers - superhero_powers.csv")
df2.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df2.drop(df2[df2['hero_names'] == '3-D Man'].index, inplace=True)

# %%
df2.loc[1,'Powers']
# Out:
# 'Accelerated Healing,Durability,Longevity,Super Strength,Stamina,Camouflage,Self-Sustenance'

# %%
df2.sort_values(['hero_names'])
# Out:
#           hero_names                                             Powers
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# 5            Abraxas  Dimensional Awareness,Flight,Intelligence,Supe...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [666 rows x 2 columns]

# %%
df2['powers_split'] = df2['Powers'].str.split(',')

# %%
df2["Powers"] = df2["Powers"].str.split(',')

# %%
exploded = df2.explode("Powers")
exploded
# Out:
#     hero_names               Powers  \
# 1       A-Bomb  Accelerated Healing
# 1       A-Bomb           Durability
# 1       A-Bomb            Longevity
# 1       A-Bomb       Super Strength
# 1       A-Bomb              Stamina
# ..         ...                  ...
# 665    Zatanna      Weather Control
# 666       Zoom          Super Speed
# 666       Zoom        Intangibility
# 666       Zoom          Time Travel
# 666       Zoom    Time Manipulation
#
#                                           powers_split
# 1    [Accelerated Healing, Durability, Longevity, S...
# 1    [Accelerated Healing, Durability, Longevity, S...
# 1    [Accelerated Healing, Durability, Longevity, S...
# 1    [Accelerated Healing, Durability, Longevity, S...
# 1    [Accelerated Healing, Durability, Longevity, S...
# ..                                                 ...
# 665  [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666  [Super Speed, Intangibility, Time Travel, Time...
# 666  [Super Speed, Intangibility, Time Travel, Time...
# 666  [Super Speed, Intangibility, Time Travel, Time...
# 666  [Super Speed, Intangibility, Time Travel, Time...
#
# [5870 rows x 3 columns]

# %%
cols_to_make = exploded['Powers'].dropna().unique()
cols_to_make
# Out:
# array(['Accelerated Healing', 'Durability', 'Longevity', 'Super Strength',
#        'Stamina', 'Camouflage', 'Self-Sustenance', 'Agility',
#        'Cold Resistance', 'Underwater breathing', 'Marksmanship',
#        'Weapons Master', 'Intelligence', 'Telepathy', 'Immortality',
#        'Reflexes', 'Enhanced Sight', 'Sub-Mariner', 'Lantern Power Ring',
#        'Super Speed', 'Invulnerability', 'Animation', 'Super Breath',
#        'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
for col in cols_to_make:
    df2[col] = df2['Powers'].str.contains(col)
df2.head()
# Out:
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\dhowa\AppData\Local\Temp\ipykernel_23276\4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
#     hero_names                                             Powers  \
# 1       A-Bomb  [Accelerated Healing, Durability, Longevity, S...
# 2   Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...
# 3     Abin Sur                               [Lantern Power Ring]
# 4  Abomination  [Accelerated Healing, Intelligence, Super Stre...
# 5      Abraxas  [Dimensional Awareness, Flight, Intelligence, ...
#
#                                         powers_split  Accelerated Healing  \
# 1  [Accelerated Healing, Durability, Longevity, S...                  NaN
# 2  [Agility, Accelerated Healing, Cold Resistance...                  NaN
# 3                               [Lantern Power Ring]                  NaN
# 4  [Accelerated Healing, Intelligence, Super Stre...                  NaN
# 5  [Dimensional Awareness, Flight, Intelligence, ...                  NaN
#
#    Durability  Longevity  Super Strength  Stamina  Camouflage  \
# 1         NaN        NaN             NaN      NaN         NaN
# 2         NaN        NaN             NaN      NaN         NaN
# 3         NaN        NaN             NaN      NaN         NaN
# 4         NaN        NaN             NaN      NaN         NaN
# 5         NaN        NaN             NaN      NaN         NaN
#
#    Self-Sustenance  ...  Weather Control  Omnipresent  Omniscient  \
# 1              NaN  ...              NaN          NaN         NaN
# 2              NaN  ...              NaN          NaN         NaN
# 3              NaN  ...              NaN          NaN         NaN
# 4              NaN  ...              NaN          NaN         NaN
# 5              NaN  ...              NaN          NaN         NaN
#
#    Hair Manipulation  Nova Force  Odin Force  Phoenix Force  \
# 1                NaN         NaN         NaN            NaN
# 2                NaN         NaN         NaN            NaN
# 3                NaN         NaN         NaN            NaN
# 4                NaN         NaN         NaN            NaN
# 5                NaN         NaN         NaN            NaN
#
#    Intuitive aptitude  Melting  Changing Armor
# 1                 NaN      NaN             NaN
# 2                 NaN      NaN             NaN
# 3                 NaN      NaN             NaN
# 4                 NaN      NaN             NaN
# 5                 NaN      NaN             NaN
#
# [5 rows x 170 columns]

# %%
df3 = pd.concat((df,df2), axis = 1)
df3.head(10)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
# 5   Male              Human      good      Blond      blue    Unknown
# 6   Male              Human      good      Brown     brown    Unknown
# 7   Male            Unknown      good    Unknown   Unknown    Unknown
# 8   Male            Unknown       bad      White      blue    Unknown
# 9   Male             Cyborg       bad      Black     brown    Unknown
#
#             Hero          Publisher Height Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0  441.0  ...             NaN
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0  ...             NaN
# 2       Abin Sur          DC Comics  185.0   90.0  ...             NaN
# 3    Abomination      Marvel Comics  203.0  441.0  ...             NaN
# 4  Absorbing Man      Marvel Comics  193.0  122.0  ...             NaN
# 5   Adam Strange          DC Comics  185.0   88.0  ...             NaN
# 6      Agent Bob      Marvel Comics  178.0   81.0  ...             NaN
# 7     Agent Zero      Marvel Comics  191.0  104.0  ...             NaN
# 8     Air-Walker      Marvel Comics  188.0  108.0  ...             NaN
# 9           Ajax      Marvel Comics  193.0   90.0  ...             NaN
#
#   Omnipresent Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0         NaN        NaN                NaN         NaN         NaN
# 1         NaN        NaN                NaN         NaN         NaN
# 2         NaN        NaN                NaN         NaN         NaN
# 3         NaN        NaN                NaN         NaN         NaN
# 4         NaN        NaN                NaN         NaN         NaN
# 5         NaN        NaN                NaN         NaN         NaN
# 6         NaN        NaN                NaN         NaN         NaN
# 7         NaN        NaN                NaN         NaN         NaN
# 8         NaN        NaN                NaN         NaN         NaN
# 9         NaN        NaN                NaN         NaN         NaN
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0            NaN                 NaN      NaN             NaN
# 1            NaN                 NaN      NaN             NaN
# 2            NaN                 NaN      NaN             NaN
# 3            NaN                 NaN      NaN             NaN
# 4            NaN                 NaN      NaN             NaN
# 5            NaN                 NaN      NaN             NaN
# 6            NaN                 NaN      NaN             NaN
# 7            NaN                 NaN      NaN             NaN
# 8            NaN                 NaN      NaN             NaN
# 9            NaN                 NaN      NaN             NaN
#
# [10 rows x 180 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 180 entries, Gender to Changing Armor
# dtypes: float64(167), object(13)
# memory usage: 938.1+ KB

# %%
merged = pd.merge (df, df2, left_on = 'Hero', right_on = 'hero_names')
merged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0  441.0  ...             NaN
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0  ...             NaN
# 2       Abin Sur          DC Comics  185.0   90.0  ...             NaN
# 3    Abomination      Marvel Comics  203.0  441.0  ...             NaN
# 4  Absorbing Man      Marvel Comics  193.0  122.0  ...             NaN
#
#   Omnipresent Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0         NaN        NaN                NaN         NaN         NaN
# 1         NaN        NaN                NaN         NaN         NaN
# 2         NaN        NaN                NaN         NaN         NaN
# 3         NaN        NaN                NaN         NaN         NaN
# 4         NaN        NaN                NaN         NaN         NaN
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0            NaN                 NaN      NaN             NaN
# 1            NaN                 NaN      NaN             NaN
# 2            NaN                 NaN      NaN             NaN
# 3            NaN                 NaN      NaN             NaN
# 4            NaN                 NaN      NaN             NaN
#
# [5 rows x 180 columns]

# %%
merged.groupby('Super Speed')['Weight'].mean()
# Out:
# Series([], Name: Weight, dtype: object)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Columns: 180 entries, Gender to Changing Armor
# dtypes: float64(167), object(13)
# memory usage: 654.7+ KB
